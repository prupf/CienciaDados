# %% [markdown]
# # Resumo Semana 1 – Fundamentos
# **Início:** 12/11/2025 │ **Usuário:** Pedro R. P. Viana

# %% [markdown]
# ## 1. Vetores e Matrizes
# $$ \vec{v} = \begin{bmatrix} 3 \\ 2 \end{bmatrix}, \quad 2\vec{v} = \begin{bmatrix} 6 \\ 4 \end{bmatrix} $$

# %% [markdown]
# ## 2. Estatística básica
# Dados: [7, 8, 6, 9, 7, 8, 10]
# Média = 7.86 │ Mediana = 8 │ Desvio padrão ≈ 1.21

# %%
# 3. Média entre várias notas

notas = [7.5, 8.0, 6.5, 9.0, 8.5]
print(f"Média: {sum(notas)/len(notas):.2f}")
# Out:
# Média: 7.90

# %%
# 4. Adicione um gráfico rápido:

import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], [2,4,1,5,3])
plt.title("Gráfico 01")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Gráfico de Seno')
plt.xlabel('x')
plt.ylabel('sen(x)')
#plt.grid(True)
plt.show()
